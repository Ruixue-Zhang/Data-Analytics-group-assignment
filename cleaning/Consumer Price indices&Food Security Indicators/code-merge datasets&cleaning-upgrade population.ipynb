# %% [markdown]
# # Data Pre-processing for Group assignment

# %% [markdown]
# ## Part 1: Formatting and merge datasets

# %% [markdown]
# In this part, we will tidy the form of two raw datasets, and finally merge them into one dataset.

# %% [markdown]
# ### 1.1  Formatting Food Security Indicators dataset

# %% [markdown]
# ***Import libraries and read dataset***

# %%
import numpy as np
import pandas as pd
df1=pd.read_csv('ASEAN_Food Security Indicators-raw.csv')
df1.head()
# Out:
#   Domain Code                             Domain  Area Code (FAO)  \
# 0          FS  Suite of Food Security Indicators               26
# 1          FS  Suite of Food Security Indicators               26
# 2          FS  Suite of Food Security Indicators               26
# 3          FS  Suite of Food Security Indicators               26
# 4          FS  Suite of Food Security Indicators               26
#
#                 Area  Element Code Element  Item Code  \
# 0  Brunei Darussalam          6121   Value      21010
# 1  Brunei Darussalam          6121   Value      21010
# 2  Brunei Darussalam          6121   Value      21010
# 3  Brunei Darussalam          6121   Value      21010
# 4  Brunei Darussalam          6121   Value      21010
#
#                                                 Item  Year Code       Year  \
# 0  Average dietary energy supply adequacy (percen...   20002002  2000-2002
# 1  Average dietary energy supply adequacy (percen...   20012003  2001-2003
# 2  Average dietary energy supply adequacy (percen...   20022004  2002-2004
# 3  Average dietary energy supply adequacy (percen...   20032005  2003-2005
# 4  Average dietary energy supply adequacy (percen...   20042006  2004-2006
#
#   Unit Value Flag Flag Description  Note
# 0    %   123    F     FAO estimate   NaN
# 1    %   125    F     FAO estimate   NaN
# 2    %   127    F     FAO estimate   NaN
# 3    %   127    F     FAO estimate   NaN
# 4    %   127    F     FAO estimate   NaN

# %% [markdown]
# ***Drop useless or duplicated columns***

# %%
df1=df1.drop(['Domain Code', 'Domain','Area Code (FAO)', 'Year Code','Element Code','Element',
            'Item Code','Unit', 'Flag',
              'Flag Description','Note'], axis=1)
df1.head()
# Out:
#                 Area                                               Item  \
# 0  Brunei Darussalam  Average dietary energy supply adequacy (percen...
# 1  Brunei Darussalam  Average dietary energy supply adequacy (percen...
# 2  Brunei Darussalam  Average dietary energy supply adequacy (percen...
# 3  Brunei Darussalam  Average dietary energy supply adequacy (percen...
# 4  Brunei Darussalam  Average dietary energy supply adequacy (percen...
#
#         Year Value
# 0  2000-2002   123
# 1  2001-2003   125
# 2  2002-2004   127
# 3  2003-2005   127
# 4  2004-2006   127

# %% [markdown]
# ***Deal with NAs***

# %%
# Compute missing values
df1.isnull().sum().sum()
# Out:
# 124

# %%
# Impute missing values to 0 temporarily
df1.fillna(0,inplace=True)
print(df1.isnull().sum())
# Out:
# Area     0
# Item     0
# Year     0
# Value    0
# dtype: int64

# %% [markdown]
# ***Formatting columns***

# %%
# Formatting 'Year' column
for i in range(len(df1)):
    if len(df1.iloc[i,2])==9:
        df1.iloc[i,2]=int((int(df1.iloc[i,2][0:4])+int(df1.iloc[i,2][5:]))/2)
        pass
    elif len(df1.iloc[i,2])==4:
        df1.iloc[i,2]=int(df1.iloc[i,2])
        pass
    else:
        print('There is an error in Year column')
        pass
    pass
df1.head()
# Out:
#                 Area                                               Item  Year  \
# 0  Brunei Darussalam  Average dietary energy supply adequacy (percen...  2001
# 1  Brunei Darussalam  Average dietary energy supply adequacy (percen...  2002
# 2  Brunei Darussalam  Average dietary energy supply adequacy (percen...  2003
# 3  Brunei Darussalam  Average dietary energy supply adequacy (percen...  2004
# 4  Brunei Darussalam  Average dietary energy supply adequacy (percen...  2005
#
#   Value
# 0   123
# 1   125
# 2   127
# 3   127
# 4   127

# %%
# Formatting 'Value' column
df1['Value'] = df1.Value.apply(str)
index = df1[df1['Value'].str.contains('<'or'>')].index
for i in index:
    df1.iloc[i,3] = df1.iloc[i,3][1:]
    pass
df1['Value'] = pd.to_numeric(df1['Value'], downcast='float')

# %% [markdown]
# ***Reshape dataframe organized by Item***

# %%
from pandas import pivot
df1=df1.pivot_table(index=['Area','Year'],columns='Item',values='Value')
df1=df1.reset_index()
df1.head()
# Out:
# 42
# Item               Area  Year  \
# 0     Brunei Darussalam  2000
# 1     Brunei Darussalam  2001
# 2     Brunei Darussalam  2002
# 3     Brunei Darussalam  2003
# 4     Brunei Darussalam  2004
#
# Item  Average dietary energy requirement (kcal/cap/day)  \
# 0                                                2323.0
# 1                                                2329.0
# 2                                                2337.0
# 3                                                2345.0
# 4                                                2352.0
#
# Item  Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                 123.0
# 2                                                 125.0
# 3                                                 127.0
# 4                                                 127.0
#
# Item  Average fat supply (g/cap/day) (3-year average)  \
# 0                                                 NaN
# 1                                           75.699997
# 2                                           78.699997
# 3                                           81.699997
# 4                                           81.000000
#
# Item  Average protein supply (g/cap/day) (3-year average)  \
# 0                                                   NaN
# 1                                             87.400002
# 2                                             89.699997
# 3                                             90.300003
# 4                                             88.599998
#
# Item  Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                                   NaN
# 1                                             45.400002
# 2                                             47.700001
# 3                                             48.299999
# 4                                             47.299999
#
# Item  Average value of food production (constant 2004-2006 I$/cap) (3-year average)  \
# 0                                                   NaN
# 1                                                  81.0
# 2                                                  85.0
# 3                                                  86.0
# 4                                                  76.0
#
# Item  Cereal import dependency ratio (percent) (3-year average)  \
# 0                                                   NaN
# 1                                            100.000000
# 2                                             99.599998
# 3                                             95.699997
# 4                                             93.800003
#
# Item  Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                                  0.21
# 1                                                  0.21
# 2                                                  0.21
# 3                                                  0.21
# 4                                                  0.21
#
# Item  ...  Prevalence of anemia among women of reproductive age (15-49 years)  \
# 0     ...                                          17.100000
# 1     ...                                          16.600000
# 2     ...                                          16.299999
# 3     ...                                          16.000000
# 4     ...                                          15.700000
#
# Item  Prevalence of exclusive breastfeeding among infants 0-5 months of age  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Item  Prevalence of low birthweight (percent)  \
# 0                                        10.3
# 1                                         9.5
# 2                                         9.2
# 3                                         9.1
# 4                                         9.2
#
# Item  Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Item  Prevalence of obesity in the adult population (18 years and older)  \
# 0                                                   7.2
# 1                                                   7.5
# 2                                                   7.9
# 3                                                   8.2
# 4                                                   8.6
#
# Item  Prevalence of severe food insecurity in the total population (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Item  Prevalence of undernourishment (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                   2.6
# 2                                                   2.5
# 3                                                   2.5
# 4                                                   2.5
#
# Item  Rail lines density (total route in km per 100 square km of land area)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Item  Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)  \
# 0                                                   NaN
# 1                                                  50.0
# 2                                                  48.0
# 3                                                  47.0
# 4                                                  46.0
#
# Item  Value of food imports in total merchandise exports (percent) (3-year average)
# 0                                                   NaN
# 1                                                   5.0
# 2                                                   4.0
# 3                                                   4.0
# 4                                                   4.0
#
# [5 rows x 44 columns]

# %% [markdown]
# ### 1.2 Formatting Consumer Price indices dataset

# %% [markdown]
# ***Read dataset***

# %%
df2=pd.read_csv('ASEAN_Consumer Price Indices-raw.csv')
df2.head()
# Out:
#   Domain Code                  Domain  Area Code (M49)               Area  \
# 0          CP  Consumer Price Indices               96  Brunei Darussalam
# 1          CP  Consumer Price Indices               96  Brunei Darussalam
# 2          CP  Consumer Price Indices               96  Brunei Darussalam
# 3          CP  Consumer Price Indices               96  Brunei Darussalam
# 4          CP  Consumer Price Indices               96  Brunei Darussalam
#
#    Year Code  Year  Item Code                                        Item  \
# 0       2000  2000      23013  Consumer Prices, Food Indices (2015 = 100)
# 1       2001  2001      23013  Consumer Prices, Food Indices (2015 = 100)
# 2       2002  2002      23013  Consumer Prices, Food Indices (2015 = 100)
# 3       2003  2003      23013  Consumer Prices, Food Indices (2015 = 100)
# 4       2004  2004      23013  Consumer Prices, Food Indices (2015 = 100)
#
#    Months Code   Months Unit      Value Flag Flag Description  \
# 0         7001  January  NaN  88.959933    F     FAO estimate
# 1         7001  January  NaN  89.702503    F     FAO estimate
# 2         7001  January  NaN  90.146512    F     FAO estimate
# 3         7001  January  NaN  90.365320    F     FAO estimate
# 4         7001  January  NaN  89.822766    F     FAO estimate
#
#                 Note
# 0  base year is 2015
# 1  base year is 2015
# 2  base year is 2015
# 3  base year is 2015
# 4  base year is 2015

# %% [markdown]
# ***Drop useless or duplicated variables***

# %%
df2=df2.drop(['Domain Code', 'Domain','Area Code (M49)', 'Year Code',
            'Item Code','Months Code', 'Flag',
              'Flag Description','Note','Unit'], axis=1)
df2.head()
# Out:
#                 Area  Year                                        Item  \
# 0  Brunei Darussalam  2000  Consumer Prices, Food Indices (2015 = 100)
# 1  Brunei Darussalam  2001  Consumer Prices, Food Indices (2015 = 100)
# 2  Brunei Darussalam  2002  Consumer Prices, Food Indices (2015 = 100)
# 3  Brunei Darussalam  2003  Consumer Prices, Food Indices (2015 = 100)
# 4  Brunei Darussalam  2004  Consumer Prices, Food Indices (2015 = 100)
#
#     Months      Value
# 0  January  88.959933
# 1  January  89.702503
# 2  January  90.146512
# 3  January  90.365320
# 4  January  89.822766

# %%
# split 'Months' column into separate columns
from pandas import pivot
df2=df2.pivot_table(index=['Area','Year','Item'],columns='Months',values='Value')
df2=df2.reset_index()
df2.head()
# Out:
# Months               Area  Year  \
# 0       Brunei Darussalam  2000
# 1       Brunei Darussalam  2000
# 2       Brunei Darussalam  2001
# 3       Brunei Darussalam  2001
# 4       Brunei Darussalam  2001
#
# Months                                           Item      April     August  \
# 0          Consumer Prices, Food Indices (2015 = 100)  89.152073  89.408259
# 1       Consumer Prices, General Indices (2015 = 100)  94.856250  95.560047
# 2          Consumer Prices, Food Indices (2015 = 100)  89.816677  89.968908
# 3       Consumer Prices, General Indices (2015 = 100)  96.185645  96.263845
# 4                                Food price inflation   0.745472   0.627067
#
# Months   December   February    January       July       June      March  \
# 0       89.664445  89.023980  88.959933  89.344212  89.280166  89.088026
# 1       95.560047  94.465251  94.230652  95.325448  95.247248  94.778050
# 2       90.121140  89.740561  89.702503  89.930850  89.892793  89.778619
# 3       92.588458  95.951046  95.872846  96.263845  96.263845  96.029246
# 4        0.509338   0.804931   0.834724   0.656604   0.686185   0.775180
#
# Months        May   November    October  September
# 0       89.216119  89.600398  89.536352  89.472305
# 1       94.856250  95.403648  95.794646  95.638247
# 2       89.854735  90.083082  90.045024  90.006966
# 3       96.185645  94.074253  96.420244  96.420244
# 4        0.715807   0.538707   0.568118   0.597571

# %%
# impute na using mean method
df2_1=df2.iloc[:,3:15]
a1=np.where(np.isnan(df2_1))[0]
a2=np.where(np.isnan(df2_1))[1]
for i in a1:
    for j in a2:
        df2_1.iloc[i,j]=df2_1.iloc[i].mean()

# %%
# add new column by mean value of months
df2['Value']=df2_1.apply(lambda x: x.mean(),axis=1)

# %%
# drop months columns
df2=df2.drop(['January','February','March','April','May','June','July','August','September','October','November','December'], axis=1)
df2.head()
# Out:
# Months               Area  Year  \
# 0       Brunei Darussalam  2000
# 1       Brunei Darussalam  2000
# 2       Brunei Darussalam  2001
# 3       Brunei Darussalam  2001
# 4       Brunei Darussalam  2001
#
# Months                                           Item      Value
# 0          Consumer Prices, Food Indices (2015 = 100)  89.312189
# 1       Consumer Prices, General Indices (2015 = 100)  95.142982
# 2          Consumer Prices, Food Indices (2015 = 100)  89.911821
# 3       Consumer Prices, General Indices (2015 = 100)  95.709930
# 4                                Food price inflation   0.671642

# %% [markdown]
# ***Reshape dataframe organized by Item***

# %%
# split the 'Item' column into Food Indices, General Indices, and inflation rates
df2=df2.pivot_table(index=['Area','Year'],columns='Item',values='Value')
df2=df2.reset_index()
df2.head()
# Out:
# Item               Area  Year  Consumer Prices, Food Indices (2015 = 100)  \
# 0     Brunei Darussalam  2000                                   89.312189
# 1     Brunei Darussalam  2001                                   89.911821
# 2     Brunei Darussalam  2002                                   90.286058
# 3     Brunei Darussalam  2003                                   90.033759
# 4     Brunei Darussalam  2004                                   90.485887
#
# Item  Consumer Prices, General Indices (2015 = 100)  Food price inflation
# 0                                         95.142982                   NaN
# 1                                         95.709930              0.671642
# 2                                         93.494272              0.416298
# 3                                         93.743590             -0.279126
# 4                                         94.530500              0.503782

# %% [markdown]
# ### 1.3 Select needed data from World Bank

# %% [markdown]
# ***Read dataset***

# %%
df3 = pd.read_csv('World Population - World Bank.csv',skiprows=[0,1,2,3])
df3.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2013         2014         2015         2016  \
# 0      57357.0  ...     103165.0     103776.0     104339.0     104865.0
# 1  148769974.0  ...  562601578.0  578075373.0  593871847.0  609978946.0
# 2    9956318.0  ...   32269592.0   33370804.0   34413603.0   35383028.0
# 3  107289875.0  ...  380437896.0  390882979.0  401586651.0  412551299.0
# 4    5770573.0  ...   26015786.0   26941773.0   27884380.0   28842482.0
#
#           2017         2018         2019         2020  2021  Unnamed: 66
# 0     105361.0     105846.0     106310.0     106766.0   NaN          NaN
# 1  626392880.0  643090131.0  660046272.0  677243299.0   NaN          NaN
# 2   36296111.0   37171922.0   38041757.0   38928341.0   NaN          NaN
# 3  423769930.0  435229381.0  446911598.0  458803476.0   NaN          NaN
# 4   29816769.0   30809787.0   31825299.0   32866268.0   NaN          NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ***Drop columns***

# %%
df3 = df3.drop(['Country Code', 'Indicator Name', 'Indicator Code','2021','Unnamed: 66'], axis = 1)
df3.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965         1966         1967  \
# 0      56699.0      57029.0      57357.0      57702.0      58044.0
# 1  141202036.0  144920186.0  148769974.0  152752671.0  156876454.0
# 2    9543200.0    9744772.0    9956318.0   10174840.0   10399936.0
# 3  102691339.0  104953470.0  107289875.0  109701811.0  112195950.0
# 4    5679409.0    5734995.0    5770573.0    5781305.0    5774440.0
#
#           1968  ...         2011         2012         2013         2014  \
# 0      58377.0  ...     102050.0     102565.0     103165.0     103776.0
# 1  161156430.0  ...  532760424.0  547482863.0  562601578.0  578075373.0
# 2   10637064.0  ...   30117411.0   31161378.0   32269592.0   33370804.0
# 3  114781116.0  ...  360285439.0  370243017.0  380437896.0  390882979.0
# 4    5771973.0  ...   24220660.0   25107925.0   26015786.0   26941773.0
#
#           2015         2016         2017         2018         2019  \
# 0     104339.0     104865.0     105361.0     105846.0     106310.0
# 1  593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2   34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3  401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4   27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
#
#           2020
# 0     106766.0
# 1  677243299.0
# 2   38928341.0
# 3  458803476.0
# 4   32866268.0
#
# [5 rows x 62 columns]

# %% [markdown]
# ***Select year 2000 - 2020***

# %%
year = np.arange(2000,2021)
col = ['Country Name']
for i in year:
    col.append(str(i))
df3 = df3[col]
df3.head()
# Out:
#                   Country Name         2000         2001         2002  \
# 0                        Aruba      90866.0      92892.0      94992.0
# 1  Africa Eastern and Southern  398113044.0  408522129.0  419223717.0
# 2                  Afghanistan   20779957.0   21606992.0   22600774.0
# 3   Africa Western and Central  267214544.0  274433894.0  281842480.0
# 4                       Angola   16395477.0   16945753.0   17519418.0
#
#           2003         2004         2005         2006         2007  \
# 0      97016.0      98744.0     100028.0     100830.0     101226.0
# 1  430246635.0  441630149.0  453404076.0  465581372.0  478166911.0
# 2   23680871.0   24726689.0   25654274.0   26433058.0   27100542.0
# 3  289469530.0  297353098.0  305520588.0  313985474.0  322741656.0
# 4   18121477.0   18758138.0   19433604.0   20149905.0   20905360.0
#
#           2008  ...         2011         2012         2013         2014  \
# 0     101362.0  ...     102050.0     102565.0     103165.0     103776.0
# 1  491173160.0  ...  532760424.0  547482863.0  562601578.0  578075373.0
# 2   27722281.0  ...   30117411.0   31161378.0   32269592.0   33370804.0
# 3  331772330.0  ...  360285439.0  370243017.0  380437896.0  390882979.0
# 4   21695636.0  ...   24220660.0   25107925.0   26015786.0   26941773.0
#
#           2015         2016         2017         2018         2019  \
# 0     104339.0     104865.0     105361.0     105846.0     106310.0
# 1  593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2   34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3  401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4   27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
#
#           2020
# 0     106766.0
# 1  677243299.0
# 2   38928341.0
# 3  458803476.0
# 4   32866268.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ***Transpose dataset***

# %%
df3 = df3.set_index('Country Name').transpose()
df3 = df3.rename_axis('Year').reset_index()
df3.head()
#df3.iloc[0,0]
# Out:
# Country Name  Year    Aruba  Africa Eastern and Southern  Afghanistan  \
# 0             2000  90866.0                  398113044.0   20779957.0
# 1             2001  92892.0                  408522129.0   21606992.0
# 2             2002  94992.0                  419223717.0   22600774.0
# 3             2003  97016.0                  430246635.0   23680871.0
# 4             2004  98744.0                  441630149.0   24726689.0
#
# Country Name  Africa Western and Central      Angola    Albania  Andorra  \
# 0                            267214544.0  16395477.0  3089027.0  65390.0
# 1                            274433894.0  16945753.0  3060173.0  67344.0
# 2                            281842480.0  17519418.0  3051010.0  70048.0
# 3                            289469530.0  18121477.0  3039616.0  73180.0
# 4                            297353098.0  18758138.0  3026939.0  76250.0
#
# Country Name   Arab World  United Arab Emirates  ...  Virgin Islands (U.S.)  \
# 0             282344141.0             3134067.0  ...               108642.0
# 1             288432153.0             3302722.0  ...               108549.0
# 2             294665202.0             3478769.0  ...               108509.0
# 3             301113869.0             3711931.0  ...               108505.0
# 4             307862846.0             4068577.0  ...               108466.0
#
# Country Name     Vietnam   Vanuatu         World     Samoa     Kosovo  \
# 0             79910411.0  184964.0  6.114324e+09  174454.0  1700000.0
# 1             80742500.0  189209.0  6.193664e+09  175394.0  1701154.0
# 2             81534406.0  193927.0  6.272724e+09  176410.0  1702310.0
# 3             82301650.0  198960.0  6.351856e+09  177481.0  1703466.0
# 4             83062819.0  204123.0  6.431527e+09  178597.0  1704622.0
#
# Country Name  Yemen, Rep.  South Africa      Zambia    Zimbabwe
# 0              17409071.0    44967713.0  10415942.0  11881482.0
# 1              17918369.0    45571272.0  10692197.0  11923906.0
# 2              18443684.0    46150913.0  10971704.0  11954293.0
# 3              18985001.0    46719203.0  11256740.0  11982219.0
# 4              19540096.0    47291610.0  11550641.0  12019911.0
#
# [5 rows x 267 columns]

# %% [markdown]
# ***Select certain country we need***

# %%
Area = ['Brunei Darussalam', 'Cambodia', 'Indonesia',
       'Lao PDR', 'Malaysia', 'Myanmar',
       'Philippines', 'Singapore', 'Thailand', 'Vietnam']
col=['Year']
for i in Area:
    col.append(i)
df3 = df3[col]
# Out:
# Country Name  Year  Brunei Darussalam    Cambodia    Indonesia    Lao PDR  \
# 0             2000           333166.0  12155241.0  211513822.0  5323701.0
# 1             2001           340037.0  12405411.0  214427419.0  5409584.0
# 2             2002           346777.0  12637719.0  217357790.0  5493247.0
# 3             2003           353295.0  12856171.0  220309473.0  5576640.0
# 4             2004           359434.0  13066475.0  223285666.0  5662199.0
#
# Country Name    Malaysia     Myanmar  Philippines  Singapore    Thailand  \
# 0             23194252.0  46719698.0   77991757.0  4027887.0  62952639.0
# 1             23709115.0  47225119.0   79672869.0  4138012.0  63539190.0
# 2             24208391.0  47702163.0   81365260.0  4175950.0  64069093.0
# 3             24698821.0  48148907.0   83051970.0  4114826.0  64549867.0
# 4             25190647.0  48564489.0   84710544.0  4166664.0  64995303.0
#
# Country Name     Vietnam
# 0             79910411.0
# 1             80742500.0
# 2             81534406.0
# 3             82301650.0
# 4             83062819.0

# %% [markdown]
# ***Rename Areas for consistency***

# %%
df3.rename(columns = {'Lao PDR':"Lao People's Democratic Republic", 'Vietnam':'Viet Nam'}, inplace = True)
df3.head()
# Out:
# Country Name  Year  Brunei Darussalam    Cambodia    Indonesia  \
# 0             2000           333166.0  12155241.0  211513822.0
# 1             2001           340037.0  12405411.0  214427419.0
# 2             2002           346777.0  12637719.0  217357790.0
# 3             2003           353295.0  12856171.0  220309473.0
# 4             2004           359434.0  13066475.0  223285666.0
#
# Country Name  Lao People's Democratic Republic    Malaysia     Myanmar  \
# 0                                    5323701.0  23194252.0  46719698.0
# 1                                    5409584.0  23709115.0  47225119.0
# 2                                    5493247.0  24208391.0  47702163.0
# 3                                    5576640.0  24698821.0  48148907.0
# 4                                    5662199.0  25190647.0  48564489.0
#
# Country Name  Philippines  Singapore    Thailand    Viet Nam
# 0              77991757.0  4027887.0  62952639.0  79910411.0
# 1              79672869.0  4138012.0  63539190.0  80742500.0
# 2              81365260.0  4175950.0  64069093.0  81534406.0
# 3              83051970.0  4114826.0  64549867.0  82301650.0
# 4              84710544.0  4166664.0  64995303.0  83062819.0

# %% [markdown]
# ***Reshape dataframe***

# %%
df3 = pd.melt(df3, id_vars = ('Year'), value_vars = list(df3.columns[1:]),
         var_name = 'Area', value_name = 'Population_total')
df3['Year'] = df3['Year'].astype(int)
df3.head()
# Out:
#    Year               Area  Population_total
# 0  2000  Brunei Darussalam          333166.0
# 1  2001  Brunei Darussalam          340037.0
# 2  2002  Brunei Darussalam          346777.0
# 3  2003  Brunei Darussalam          353295.0
# 4  2004  Brunei Darussalam          359434.0

# %% [markdown]
# ### 1.4 Combine three datasets

# %%
# combine 3 dataframes
data = pd.concat((df.set_index(['Area','Year']) for df in [df1, df2, df3]),axis=1, join='inner').reset_index()
data.head()
# Out:
#                 Area  Year  Average dietary energy requirement (kcal/cap/day)  \
# 0  Brunei Darussalam  2000                                             2323.0
# 1  Brunei Darussalam  2001                                             2329.0
# 2  Brunei Darussalam  2002                                             2337.0
# 3  Brunei Darussalam  2003                                             2345.0
# 4  Brunei Darussalam  2004                                             2352.0
#
#    Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                NaN
# 1                                              123.0
# 2                                              125.0
# 3                                              127.0
# 4                                              127.0
#
#    Average fat supply (g/cap/day) (3-year average)  \
# 0                                              NaN
# 1                                        75.699997
# 2                                        78.699997
# 3                                        81.699997
# 4                                        81.000000
#
#    Average protein supply (g/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                          87.400002
# 2                                          89.699997
# 3                                          90.300003
# 4                                          88.599998
#
#    Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                          45.400002
# 2                                          47.700001
# 3                                          48.299999
# 4                                          47.299999
#
#    Average value of food production (constant 2004-2006 I$/cap) (3-year average)  \
# 0                                                NaN
# 1                                               81.0
# 2                                               85.0
# 3                                               86.0
# 4                                               76.0
#
#    Cereal import dependency ratio (percent) (3-year average)  \
# 0                                                NaN
# 1                                         100.000000
# 2                                          99.599998
# 3                                          95.699997
# 4                                          93.800003
#
#    Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                               0.21
# 1                                               0.21
# 2                                               0.21
# 3                                               0.21
# 4                                               0.21
#
#    ...  Prevalence of obesity in the adult population (18 years and older)  \
# 0  ...                                                7.2
# 1  ...                                                7.5
# 2  ...                                                7.9
# 3  ...                                                8.2
# 4  ...                                                8.6
#
#    Prevalence of severe food insecurity in the total population (percent) (3-year average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Prevalence of undernourishment (percent) (3-year average)  \
# 0                                                NaN
# 1                                                2.6
# 2                                                2.5
# 3                                                2.5
# 4                                                2.5
#
#    Rail lines density (total route in km per 100 square km of land area)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                               50.0
# 2                                               48.0
# 3                                               47.0
# 4                                               46.0
#
#    Value of food imports in total merchandise exports (percent) (3-year average)  \
# 0                                                NaN
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Consumer Prices, Food Indices (2015 = 100)  \
# 0                                   89.312189
# 1                                   89.911821
# 2                                   90.286058
# 3                                   90.033759
# 4                                   90.485887
#
#    Consumer Prices, General Indices (2015 = 100)  Food price inflation  \
# 0                                      95.142982                   NaN
# 1                                      95.709930              0.671642
# 2                                      93.494272              0.416298
# 3                                      93.743590             -0.279126
# 4                                      94.530500              0.503782
#
#    Population_total
# 0          333166.0
# 1          340037.0
# 2          346777.0
# 3          353295.0
# 4          359434.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ### 1.4 Save data

# %%
data.to_csv(r'ASEAN_Consumer Price&Food Security Indicators-merged.csv',index=False)

# %% [markdown]
# ## Part 2: Handle missing data

# %% [markdown]
# In this part, we use Random Forest Regressor model combined mean method to impute missing values.

# %% [markdown]
# ### 2.1 Initial understanding of the dataset

# %% [markdown]
# ***Import libraries and read dataset***

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df=pd.read_csv('ASEAN_Consumer Price&Food Security Indicators-merged.csv')
df.head()
# Out:
#                 Area  Year  Average dietary energy requirement (kcal/cap/day)  \
# 0  Brunei Darussalam  2000                                             2323.0
# 1  Brunei Darussalam  2001                                             2329.0
# 2  Brunei Darussalam  2002                                             2337.0
# 3  Brunei Darussalam  2003                                             2345.0
# 4  Brunei Darussalam  2004                                             2352.0
#
#    Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                NaN
# 1                                              123.0
# 2                                              125.0
# 3                                              127.0
# 4                                              127.0
#
#    Average fat supply (g/cap/day) (3-year average)  \
# 0                                              NaN
# 1                                             75.7
# 2                                             78.7
# 3                                             81.7
# 4                                             81.0
#
#    Average protein supply (g/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                               87.4
# 2                                               89.7
# 3                                               90.3
# 4                                               88.6
#
#    Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                               45.4
# 2                                               47.7
# 3                                               48.3
# 4                                               47.3
#
#    Average value of food production (constant 2004-2006 I$/cap) (3-year average)  \
# 0                                                NaN
# 1                                               81.0
# 2                                               85.0
# 3                                               86.0
# 4                                               76.0
#
#    Cereal import dependency ratio (percent) (3-year average)  \
# 0                                                NaN
# 1                                              100.0
# 2                                               99.6
# 3                                               95.7
# 4                                               93.8
#
#    Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                               0.21
# 1                                               0.21
# 2                                               0.21
# 3                                               0.21
# 4                                               0.21
#
#    ...  Prevalence of obesity in the adult population (18 years and older)  \
# 0  ...                                                7.2
# 1  ...                                                7.5
# 2  ...                                                7.9
# 3  ...                                                8.2
# 4  ...                                                8.6
#
#    Prevalence of severe food insecurity in the total population (percent) (3-year average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Prevalence of undernourishment (percent) (3-year average)  \
# 0                                                NaN
# 1                                                2.6
# 2                                                2.5
# 3                                                2.5
# 4                                                2.5
#
#    Rail lines density (total route in km per 100 square km of land area)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)  \
# 0                                                NaN
# 1                                               50.0
# 2                                               48.0
# 3                                               47.0
# 4                                               46.0
#
#    Value of food imports in total merchandise exports (percent) (3-year average)  \
# 0                                                NaN
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Consumer Prices, Food Indices (2015 = 100)  \
# 0                                   89.312189
# 1                                   89.911821
# 2                                   90.286058
# 3                                   90.033759
# 4                                   90.485887
#
#    Consumer Prices, General Indices (2015 = 100)  Food price inflation  \
# 0                                      95.142982                   NaN
# 1                                      95.709930              0.671642
# 2                                      93.494272              0.416298
# 3                                      93.743590             -0.279126
# 4                                      94.530500              0.503782
#
#    Population_total
# 0          333166.0
# 1          340037.0
# 2          346777.0
# 3          353295.0
# 4          359434.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ***See the dimension of dataset***

# %%
print('The dataset contains', np.shape(df)[0], 'rows and', np.shape(df)[1], 'columns.')
# Out:
# The dataset contains 210 rows and 48 columns.

# %% [markdown]
# ***See the distribution of missing data***

# %% [markdown]
# We imputed some missing values by zero for necessary when formatting the dataset, now first we change them back to NaNs.

# %%
for i in range(np.shape(df)[0]):
    for j in range(np.shape(df)[1]):
        if df.iloc[i,j] == 0:
            df.iloc[i,j] = float('NaN')

# %%
# Calculate total NAs
df.isnull().sum().sum()
# Out:
# 2520

# %%
# Visualizing Missing Data using Seaborn heatmap()
plt.figure(figsize=(10,15))
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})

# %% [markdown]
# ### 2.2 Imputation of missing data

# %% [markdown]
# #### Step 1: test correlation between complete columns and incomplete columns

# %% [markdown]
# *Convert string variables into categorical numeric variables*

# %%
# create a categorical numeric variable to result 'Area' into groups
df['Area_cat'] = df['Area'].astype('category')
df['Area_cat'] = df['Area_cat'].cat.codes
# reindex dataset
df = df.reindex(columns = df.columns)
# create df1 with no str variables to test correlation
df1 = df.drop('Area', axis = 1)

# %% [markdown]
# *Create correlation table*

# %%
# The function creates table shows Pearson Correlation Coefficient (PCC) between complete vars and incomplete vars.
def create_correlation_table(df):
    complete_col = df.loc[:,df.isnull().sum() == 0].columns
    incomplete_col=df.loc[:,df.isnull().sum() != 0].columns
    li1 = []; li2 = []; li3 = []
    for i in incomplete_col:
        for j in complete_col:
            li1.append(i)
            li2.append(j)
            li3.append(df[i].corr(df[j]))
    df_r = {'Incomplete Variables':li1,
           'Complete Variables':li2,
           'PCC':li3}
    df_r = pd.DataFrame(df_r)
    return df_r
df1_r = create_correlation_table(df1) 
df1_r.head(20)
# Out:
#                                  Incomplete Variables  \
# 0   Average dietary energy supply adequacy (percen...
# 1   Average dietary energy supply adequacy (percen...
# 2   Average dietary energy supply adequacy (percen...
# 3   Average dietary energy supply adequacy (percen...
# 4   Average dietary energy supply adequacy (percen...
# 5   Average dietary energy supply adequacy (percen...
# 6   Average dietary energy supply adequacy (percen...
# 7   Average dietary energy supply adequacy (percen...
# 8   Average dietary energy supply adequacy (percen...
# 9   Average dietary energy supply adequacy (percen...
# 10  Average dietary energy supply adequacy (percen...
# 11  Average dietary energy supply adequacy (percen...
# 12  Average dietary energy supply adequacy (percen...
# 13    Average fat supply (g/cap/day) (3-year average)
# 14    Average fat supply (g/cap/day) (3-year average)
# 15    Average fat supply (g/cap/day) (3-year average)
# 16    Average fat supply (g/cap/day) (3-year average)
# 17    Average fat supply (g/cap/day) (3-year average)
# 18    Average fat supply (g/cap/day) (3-year average)
# 19    Average fat supply (g/cap/day) (3-year average)
#
#                                    Complete Variables       PCC
# 0                                                Year  0.563240
# 1   Average dietary energy requirement (kcal/cap/day)  0.376543
# 2   Gross domestic product per capita, PPP, dissem...  0.587843
# 3   Minimum dietary energy requirement  (kcal/cap/...  0.373129
# 4   Number of children under 5 years of age who ar...  0.152125
# 5   Number of children under 5 years of age who ar... -0.035140
# 6   Percentage of children under 5 years of age wh...  0.492947
# 7   Percentage of children under 5 years of age wh... -0.685287
# 8   Percentage of population using at least basic ...  0.750141
# 9          Consumer Prices, Food Indices (2015 = 100)  0.779187
# 10      Consumer Prices, General Indices (2015 = 100)  0.767176
# 11                                   Population_total  0.057232
# 12                                           Area_cat -0.151119
# 13                                               Year  0.217392
# 14  Average dietary energy requirement (kcal/cap/day)  0.507332
# 15  Gross domestic product per capita, PPP, dissem...  0.503341
# 16  Minimum dietary energy requirement  (kcal/cap/...  0.496367
# 17  Number of children under 5 years of age who ar... -0.055223
# 18  Number of children under 5 years of age who ar... -0.159916
# 19  Percentage of children under 5 years of age wh...  0.481642

# %% [markdown]
# #### Step 2: create and test model

# %% [markdown]
# We create a model to impute NAs base on *Seaborn Random Forest Regressor*, using *Mean Square Error* to test model.

# %% [markdown]
# *Some introduction of the model:*
#
#      X_train - This includes all independent variables, will be used to train the model.
#
#      X_test - The remaining portion of the independent variables from the data which will not be used in the training phase and will be used to make predictions to test the accuracy of the model.
#
#      y_train - This is dependent variable which needs to be predicted by this model, including category labels against your independent variables, we need to specify our dependent variable while training/fitting the model.
#
#      y_test - This data has category labels for the test data, these labels will be used to test the accuracy between actual and predicted categories.

# %%
# This function is used to test model by Mean Square Error (MSE).
def test_model(df,df_r):
    import warnings
    warnings.filterwarnings('ignore')     # ignore warning message
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.metrics import mean_squared_error
    from sklearn.model_selection import KFold
    kf = KFold(n_splits = 10, random_state = 42)    # n_splits = number of folds, random_state ensure the splits are reproducible
    incomplete_col = df.loc[:,df.isnull().sum() != 0].columns
    
    # get absolute value of PCC to select 3 strongest correlated vars of each incomplete var
    df_neg2pos = df_r.copy()
    for index in range(len(df_r.PCC)):
            if df_r.PCC[index] < 0:
                df_neg2pos.PCC[index] = -df_r.PCC[index]
                
    for i in incomplete_col:
        df_missing = df[df[i].isnull()].copy()
        df_filter = df.merge(df_missing,how='outer',indicator=True).query('_merge == "left_only"').drop('_merge',1).copy()
        y_pred_rf = []
        y_true_rf = []
        df_split = df_neg2pos[df_neg2pos.iloc[:,0] == i]     # split correlation table by each incomplete variable
        df_split.sort_values(by = ['PCC'], ascending = False, inplace = True)   # sort PCC of each i in incomplete_col
        # correlation-based feature selection
        features = list(df_split.iloc[:3,1].values)       # add 3 strongest correlated vars of each i into features
        features.append('Area_cat')                   # add features
        features.append('Year')                      # add features
        features = list(dict.fromkeys(features))           #de‑duplicate
        
        for train_index,test_index in kf.split(df_filter):
            df_test = df_filter.iloc[test_index]
            df_train = df_filter.iloc[train_index]
            # X - input, y - output
            X_train = np.array(df_train[features])     
            y_train = np.array(df_train[i])            # the label of each instance
            X_test = np.array(df_test[features])     
            y_test = np.array(df_test[i])        # the set of labels to all the data in x_test
            model = RandomForestRegressor(n_estimators = 200, max_depth = 100, random_state = 42)
            model.fit(X_train,y_train)
            y_pred_rf.append(model.predict(X_test)[0])
            y_true_rf.append(y_test[0])
        print('Mean Square Error(Random Forest) for',i,':',mean_squared_error(y_pred_rf,y_true_rf).round(3))
test_model(df1,df1_r)
# Out:
# Mean Square Error(Random Forest) for Average dietary energy supply adequacy (percent) (3-year average) : 27.802
# Mean Square Error(Random Forest) for Average fat supply (g/cap/day) (3-year average) : 105.646
# Mean Square Error(Random Forest) for Average protein supply (g/cap/day) (3-year average) : 55.218
# Mean Square Error(Random Forest) for Average supply of protein of animal origin (g/cap/day) (3-year average) : 9.472
# Mean Square Error(Random Forest) for Average value of food production (constant 2004-2006 I$/cap) (3-year average) : 10219.342
# Mean Square Error(Random Forest) for Cereal import dependency ratio (percent) (3-year average) : 609.244
# Mean Square Error(Random Forest) for Coefficient of variation of habitual caloric consumption distribution (real number) : 0.0
# Mean Square Error(Random Forest) for Dietary energy supply used in the estimation of prevalence of undernourishment (kcal/cap/day) (3-year average) : 7331.578
# Mean Square Error(Random Forest) for Incidence of caloric losses at retail distribution level (percent) : 0.011
# Mean Square Error(Random Forest) for Number of children under 5 years affected by wasting (million) : 0.045
# Mean Square Error(Random Forest) for Number of moderately or severely food insecure people (million) (3-year average) : 44.898
# Mean Square Error(Random Forest) for Number of newborns with low birthweight (million) : 18658.634
# Mean Square Error(Random Forest) for Number of obese adults (18 years and older) (million) : 0.194
# Mean Square Error(Random Forest) for Number of people undernourished (million) (3-year average) : 2.65
# Mean Square Error(Random Forest) for Number of severely food insecure people (million) (3-year average) : 1.885
# Mean Square Error(Random Forest) for Number of women of reproductive age (15-49 years) affected by anemia (million) : 0.158
# Mean Square Error(Random Forest) for Per capita food production variability (constant 2004-2006 thousand int$ per capita) : 45.971
# Mean Square Error(Random Forest) for Per capita food supply variability (kcal/cap/day) : 63.355
# Mean Square Error(Random Forest) for Percent of arable land equipped for irrigation (percent) (3-year average) : 64.522
# Mean Square Error(Random Forest) for Percentage of children under 5 years affected by wasting (percent) : 15.531
# Mean Square Error(Random Forest) for Percentage of population using at least basic sanitation services (percent) : 6.075
# Mean Square Error(Random Forest) for Percentage of population using safely managed drinking water services (Percent) : 8.768
# Mean Square Error(Random Forest) for Percentage of population using safely managed sanitation services (Percent) : 137.49
# Mean Square Error(Random Forest) for Political stability and absence of violence/terrorism (index) : 1.063
# Mean Square Error(Random Forest) for Prevalence of anemia among women of reproductive age (15-49 years) : 98.802
# Mean Square Error(Random Forest) for Prevalence of exclusive breastfeeding among infants 0-5 months of age : 239.373
# Mean Square Error(Random Forest) for Prevalence of low birthweight (percent) : 26.644
# Mean Square Error(Random Forest) for Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average) : 106.458
# Mean Square Error(Random Forest) for Prevalence of obesity in the adult population (18 years and older) : 5.224
# Mean Square Error(Random Forest) for Prevalence of severe food insecurity in the total population (percent) (3-year average) : 8.732
# Mean Square Error(Random Forest) for Prevalence of undernourishment (percent) (3-year average) : 1.165
# Mean Square Error(Random Forest) for Rail lines density (total route in km per 100 square km of land area) : 0.014
# Mean Square Error(Random Forest) for Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average) : 68.813
# Mean Square Error(Random Forest) for Value of food imports in total merchandise exports (percent) (3-year average) : 26.65
# Mean Square Error(Random Forest) for Food price inflation : 22.815

# %% [markdown]
# As shown above, the model for most incomplete variables performs good, while for others it has large mean-squared errors. So I plan to use mean by Area to impute the NaNs of those variables as they don't have large miss values.

# %% [markdown]
# #### Step 3: Deal with those variables with bad model performance but less missing values

# %%
# get index
df2=df1.copy()
print(df2.columns.get_loc('Dietary energy supply used in the estimation of prevalence of undernourishment (kcal/cap/day) (3-year average)'),
      df2.columns.get_loc('Number of newborns with low birthweight (million)'),
      df2.columns.get_loc('Average value of food production (constant 2004-2006 I$/cap) (3-year average)'),
      df2.columns.get_loc('Cereal import dependency ratio (percent) (3-year average)'))
# Out:
# 9 17 6 7

# %%
# fill na by Area mean
df2.iloc[:,9] = df2.iloc[:,9].fillna(df2.groupby('Area_cat')['Dietary energy supply used in the estimation of prevalence of undernourishment (kcal/cap/day) (3-year average)'].transform('mean'))
df2.iloc[:,17] = df2.iloc[:,17].fillna(df2.groupby('Area_cat')['Number of newborns with low birthweight (million)'].transform('mean'))
df2.iloc[:,6] = df2.iloc[:,6].fillna(df2.groupby('Area_cat')['Average value of food production (constant 2004-2006 I$/cap) (3-year average)'].transform('mean'))
df2.iloc[:,7] = df2.iloc[:,7].fillna(df2.groupby('Area_cat')['Cereal import dependency ratio (percent) (3-year average)'].transform('mean'))
df2_r=create_correlation_table(df2)

# %% [markdown]
# #### Step 4: impute NaNs using Random Forest Regressor model

# %%
def Impute_NaN(df,df_r):
    import warnings
    warnings.filterwarnings('ignore')
    from sklearn.ensemble import RandomForestRegressor
    incomplete_col = df.loc[:,df.isnull().sum() != 0].columns
    df_neg2pos = df_r.copy()
    for index in range(len(df_r.PCC)):
            if df_r.PCC[index] < 0:
                df_neg2pos.PCC[index] = -df_r.PCC[index]
    for i in incomplete_col:
        df_missing = df[df[i].isnull()].copy()
        df_filter = df.merge(df_missing,how='outer',indicator=True).query('_merge == "left_only"').drop('_merge',1).copy()
        df_split = df_neg2pos[df_neg2pos.iloc[:,0]==i]
        df_split.sort_values(by = ['PCC'], ascending = False, inplace = True)
        features = list(df_split.iloc[:3,1].values)
        features.append('Area_cat')
        features.append('Year')
        features = list(dict.fromkeys(features))
        X_test_rf = np.array(df_missing[features])
        X_train_rf = np.array(df_filter[features])
        y_train_rf = np.array(df_filter[i])
        model_rf = RandomForestRegressor(n_estimators=200, max_depth=100, random_state=42)
        model_rf.fit(X_train_rf,y_train_rf)
        y_test_rf = model_rf.predict(X_test_rf)
        df.loc[df[i].isnull(),i] = y_test_rf
    return df

# %%
Impute_NaN(df2,df2_r)
# Out:
#      Year  Average dietary energy requirement (kcal/cap/day)  \
# 0    2000                                             2323.0
# 1    2001                                             2329.0
# 2    2002                                             2337.0
# 3    2003                                             2345.0
# 4    2004                                             2352.0
# ..    ...                                                ...
# 205  2016                                             2302.0
# 206  2017                                             2299.0
# 207  2018                                             2297.0
# 208  2019                                             2295.0
# 209  2020                                             2294.0
#
#      Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                               123.77
# 1                                               123.00
# 2                                               125.00
# 3                                               127.00
# 4                                               127.00
# ..                                                 ...
# 205                                             125.00
# 206                                             126.00
# 207                                             127.00
# 208                                             127.00
# 209                                             124.66
#
#      Average fat supply (g/cap/day) (3-year average)  \
# 0                                            78.2105
# 1                                            75.7000
# 2                                            78.7000
# 3                                            81.7000
# 4                                            81.0000
# ..                                               ...
# 205                                          80.4000
# 206                                          83.4000
# 207                                          81.5115
# 208                                          81.8700
# 209                                          81.8480
#
#      Average protein supply (g/cap/day) (3-year average)  \
# 0                                              87.8440
# 1                                              87.4000
# 2                                              89.7000
# 3                                              90.3000
# 4                                              88.6000
# ..                                                 ...
# 205                                            94.3000
# 206                                            96.0000
# 207                                            89.0855
# 208                                            88.6530
# 209                                            88.6405
#
#      Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                              46.3130
# 1                                              45.4000
# 2                                              47.7000
# 3                                              48.3000
# 4                                              47.3000
# ..                                                 ...
# 205                                            37.3000
# 206                                            37.7000
# 207                                            35.0465
# 208                                            34.3115
# 209                                            34.6945
#
#      Average value of food production (constant 2004-2006 I$/cap) (3-year average)  \
# 0                                            93.000000
# 1                                            81.000000
# 2                                            85.000000
# 3                                            86.000000
# 4                                            76.000000
# ..                                                 ...
# 205                                         201.000000
# 206                                          99.000000
# 207                                         250.823529
# 208                                         250.823529
# 209                                         250.823529
#
#      Cereal import dependency ratio (percent) (3-year average)  \
# 0                                            94.133333
# 1                                           100.000000
# 2                                            99.600000
# 3                                            95.700000
# 4                                            93.800000
# ..                                                 ...
# 205                                           4.900000
# 206                                           8.300000
# 207                                          -8.464706
# 208                                          -8.464706
# 209                                          -8.464706
#
#      Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                                 0.21
# 1                                                 0.21
# 2                                                 0.21
# 3                                                 0.21
# 4                                                 0.21
# ..                                                 ...
# 205                                               0.28
# 206                                               0.28
# 207                                               0.28
# 208                                               0.28
# 209                                               0.29
#
#      Dietary energy supply used in the estimation of prevalence of undernourishment (kcal/cap/day) (3-year average)  \
# 0                                          3024.157895
# 1                                          2859.000000
# 2                                          2923.000000
# 3                                          2971.000000
# 4                                          2996.000000
# ..                                                 ...
# 205                                        2864.000000
# 206                                        2892.000000
# 207                                        2915.000000
# 208                                        2921.000000
# 209                                        2680.315789
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 205  ...
# 206  ...
# 207  ...
# 208  ...
# 209  ...
#
#      Prevalence of severe food insecurity in the total population (percent) (3-year average)  \
# 0                                               6.9585
# 1                                               6.9585
# 2                                               6.9585
# 3                                               6.9585
# 4                                               6.9585
# ..                                                 ...
# 205                                             1.6370
# 206                                             0.5000
# 207                                             0.5000
# 208                                             0.5000
# 209                                             3.6110
#
#      Prevalence of undernourishment (percent) (3-year average)  \
# 0                                                2.563
# 1                                                2.600
# 2                                                2.500
# 3                                                2.500
# 4                                                2.500
# ..                                                 ...
# 205                                              7.800
# 206                                              7.200
# 207                                              6.800
# 208                                              6.700
# 209                                              8.310
#
#      Rail lines density (total route in km per 100 square km of land area)  \
# 0                                               0.4910
# 1                                               0.4910
# 2                                               0.4910
# 3                                               0.4910
# 4                                               0.4910
# ..                                                 ...
# 205                                             0.8000
# 206                                             0.7000
# 207                                             0.7000
# 208                                             0.7135
# 209                                             0.7135
#
#      Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)  \
# 0                                               48.335
# 1                                               50.000
# 2                                               48.000
# 3                                               47.000
# 4                                               46.000
# ..                                                 ...
# 205                                             54.000
# 206                                             53.000
# 207                                             52.730
# 208                                             52.485
# 209                                             51.880
#
#      Value of food imports in total merchandise exports (percent) (3-year average)  \
# 0                                                4.575
# 1                                                5.000
# 2                                                4.000
# 3                                                4.000
# 4                                                4.000
# ..                                                 ...
# 205                                              6.000
# 206                                              6.000
# 207                                              5.000
# 208                                              5.395
# 209                                              4.390
#
#      Consumer Prices, Food Indices (2015 = 100)  \
# 0                                     89.312189
# 1                                     89.911821
# 2                                     90.286058
# 3                                     90.033759
# 4                                     90.485887
# ..                                          ...
# 205                                  102.363624
# 206                                  101.258549
# 207                                  104.536628
# 208                                  108.797175
# 209                                  119.628332
#
#      Consumer Prices, General Indices (2015 = 100)  Food price inflation  \
# 0                                        95.142982              0.484959
# 1                                        95.709930              0.671642
# 2                                        93.494272              0.416298
# 3                                        93.743590             -0.279126
# 4                                        94.530500              0.503782
# ..                                             ...                   ...
# 205                                     102.668808              2.363180
# 206                                     106.283014             -1.072609
# 207                                     110.045037              3.254676
# 208                                     113.121703              4.078947
# 209                                     116.765278             10.020975
#
#      Population_total  Area_cat
# 0            333166.0         0
# 1            340037.0         0
# 2            346777.0         0
# 3            353295.0         0
# 4            359434.0         0
# ..                ...       ...
# 205        93640435.0         9
# 206        94600643.0         9
# 207        95545959.0         9
# 208        96462108.0         9
# 209        97338583.0         9
#
# [210 rows x 48 columns]

# %% [markdown]
# *Count NaNs after imputation*

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# *Add 'Area' column back to cleaned dataset (df2)*

# %%
df_Area = pd.DataFrame(df.iloc[:,0])
df_cleaned = df_Area.join(df2)
df_cleaned.head()
# Out:
#                 Area  Year  Average dietary energy requirement (kcal/cap/day)  \
# 0  Brunei Darussalam  2000                                             2323.0
# 1  Brunei Darussalam  2001                                             2329.0
# 2  Brunei Darussalam  2002                                             2337.0
# 3  Brunei Darussalam  2003                                             2345.0
# 4  Brunei Darussalam  2004                                             2352.0
#
#    Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                             123.77
# 1                                             123.00
# 2                                             125.00
# 3                                             127.00
# 4                                             127.00
#
#    Average fat supply (g/cap/day) (3-year average)  \
# 0                                          78.2105
# 1                                          75.7000
# 2                                          78.7000
# 3                                          81.7000
# 4                                          81.0000
#
#    Average protein supply (g/cap/day) (3-year average)  \
# 0                                             87.844
# 1                                             87.400
# 2                                             89.700
# 3                                             90.300
# 4                                             88.600
#
#    Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                             46.313
# 1                                             45.400
# 2                                             47.700
# 3                                             48.300
# 4                                             47.300
#
#    Average value of food production (constant 2004-2006 I$/cap) (3-year average)  \
# 0                                               93.0
# 1                                               81.0
# 2                                               85.0
# 3                                               86.0
# 4                                               76.0
#
#    Cereal import dependency ratio (percent) (3-year average)  \
# 0                                          94.133333
# 1                                         100.000000
# 2                                          99.600000
# 3                                          95.700000
# 4                                          93.800000
#
#    Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                               0.21
# 1                                               0.21
# 2                                               0.21
# 3                                               0.21
# 4                                               0.21
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Prevalence of severe food insecurity in the total population (percent) (3-year average)  \
# 0                                             6.9585
# 1                                             6.9585
# 2                                             6.9585
# 3                                             6.9585
# 4                                             6.9585
#
#    Prevalence of undernourishment (percent) (3-year average)  \
# 0                                              2.563
# 1                                              2.600
# 2                                              2.500
# 3                                              2.500
# 4                                              2.500
#
#    Rail lines density (total route in km per 100 square km of land area)  \
# 0                                              0.491
# 1                                              0.491
# 2                                              0.491
# 3                                              0.491
# 4                                              0.491
#
#    Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)  \
# 0                                             48.335
# 1                                             50.000
# 2                                             48.000
# 3                                             47.000
# 4                                             46.000
#
#    Value of food imports in total merchandise exports (percent) (3-year average)  \
# 0                                              4.575
# 1                                              5.000
# 2                                              4.000
# 3                                              4.000
# 4                                              4.000
#
#    Consumer Prices, Food Indices (2015 = 100)  \
# 0                                   89.312189
# 1                                   89.911821
# 2                                   90.286058
# 3                                   90.033759
# 4                                   90.485887
#
#    Consumer Prices, General Indices (2015 = 100)  Food price inflation  \
# 0                                      95.142982              0.484959
# 1                                      95.709930              0.671642
# 2                                      93.494272              0.416298
# 3                                      93.743590             -0.279126
# 4                                      94.530500              0.503782
#
#    Population_total  Area_cat
# 0          333166.0         0
# 1          340037.0         0
# 2          346777.0         0
# 3          353295.0         0
# 4          359434.0         0
#
# [5 rows x 49 columns]

# %% [markdown]
# *Some visualisation of cleaned dataset*

# %%
import seaborn as sns
sns.set(style = 'ticks')
sns.lmplot(x = 'Year',
           y = 'Number of severely food insecure people (million) (3-year average)',
           col = 'Area',
           data = df_cleaned,
           col_wrap = 2,
           height = 4)

# %% [markdown]
# ##### Split into different datasets by Area （Optional）

# %%
data = np.array_split(df_cleaned, 10)
df_Brunei = data[0].iloc[:,1:-1]
df_Cambodia = data[1].iloc[:,1:-1]
df_Indonesia = data[2].iloc[:,1:-1]
df_Lao = data[3].iloc[:, 1:-1]
df_Malaysia = data[4].iloc[:,1:-1]
df_Myanmar = data[5].iloc[:,1:-1]
df_Philippines = data[6].iloc[:,1:-1]
df_Singapore = data[7].iloc[:,1:-1]
df_Thailand = data[8].iloc[:,1:-1]
df_VietNam = data[9].iloc[:,1:-1]

# %% [markdown]
# ##### Save data

# %%
df_cleaned.to_csv(r'ASEAN_Consumer Price&Food Security Indicators-cleaned.csv',index=False)
# df_Brunei.to_csv(r'Brunei_Consumer Price&Food Security Indicators.csv',index=False)
# df_Cambodia.to_csv(r'Cambodia_Consumer Price&Food Security Indicators.csv',index=False)
# df_Indonesia.to_csv(r'Indonesia_Consumer Price&Food Security Indicators.csv',index=False)
# df_Lao.to_csv(r'Lao_Consumer Price&Food Security Indicators.csv',index=False)
# df_Malaysia.to_csv(r'Malaysia_Consumer Price&Food Security Indicators.csv',index=False)
# df_Myanmar.to_csv(r'Myanmar_Consumer Price&Food Security Indicators.csv',index=False)
# df_Philippines.to_csv(r'Philippines_Consumer Price&Food Security Indicators.csv',index=False)
# df_Singapore.to_csv(r'Singapore_Consumer Price&Food Security Indicators.csv',index=False)
# df_Thailand.to_csv(r'Thailand_Consumer Price&Food Security Indicators.csv',index=False)
# df_VietNam.to_csv(r'VietNam_Consumer Price&Food Security Indicators.csv',index=False)
